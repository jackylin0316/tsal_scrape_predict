# %%
from datetime import datetime, timedelta
today = datetime.today()
one_year_ago=today-timedelta(365)
one_year_ago.
# weekday_number = today.weekday()
# weekday_number 
# if weekday_number==5:
#      date=today-timedelta(1)
# if weekday_number==6:
#      date=today-timedelta(2)
# Out:
# <function datetime.date>

# %%
# 0 = Monday, 6 = Sunday
# Out:
# datetime.datetime(2025, 4, 15, 11, 54, 29, 136048)

# %%
today=datetime.today()
weekday_number=today.weekday
if weekday_number==5:
        today=today-timedelta(1)
if weekday_number==6:
        today=today-timedelta(2)
one_year_before=today-timedelta(365)
weekday_number=one_year_before.weekday
if weekday_number==5:
        one_year_before=today-timedelta(1)
if weekday_number==6:
        one_year_before=today-timedelta(2)
formatted = today.strftime("%b %d, %Y")
past_formatted=one_year_before.strftime("%b %d, %Y")
print(past_formatted+' - '+formatted)
# Out:
# Apr 15, 2024 - Apr 15, 2025

# %%
import pandas as pd
df = {
    "Date": ["Apr 14, 2025", "Apr 11, 2025", "Apr 10, 2025", "Apr 9, 2025", "Apr 8, 2025"],
    "Open": [258.36, 251.84, 260.00, 224.69, 245.00],
    "High": [261.80, 257.74, 262.49, 274.69, 250.44],
    "Low": [245.93, 241.36, 239.33, 223.88, 217.80],
    "Close": [252.35, 252.31, 252.40, 272.20, 221.86],
    "Adj Close": [252.35, 252.31, 252.40, 272.20, 221.86],
    "Volume": ["99,696,500", "128,948,100", "181,722,600", "219,433,400", "171,603,500"]
}
df=pd.DataFrame(df)

# %%
df
# Out:
#            Date    Open    High     Low   Close  Adj Close       Volume
# 0  Apr 14, 2025  258.36  261.80  245.93  252.35     252.35   99,696,500
# 1  Apr 11, 2025  251.84  257.74  241.36  252.31     252.31  128,948,100
# 2  Apr 10, 2025  260.00  262.49  239.33  252.40     252.40  181,722,600
# 3   Apr 9, 2025  224.69  274.69  223.88  272.20     272.20  219,433,400
# 4   Apr 8, 2025  245.00  250.44  217.80  221.86     221.86  171,603,500

# %%
df=df[::-1]
df
# Out:
#            Date    Open    High     Low   Close  Adj Close       Volume
# 4   Apr 8, 2025  245.00  250.44  217.80  221.86     221.86  171,603,500
# 3   Apr 9, 2025  224.69  274.69  223.88  272.20     272.20  219,433,400
# 2  Apr 10, 2025  260.00  262.49  239.33  252.40     252.40  181,722,600
# 1  Apr 11, 2025  251.84  257.74  241.36  252.31     252.31  128,948,100
# 0  Apr 14, 2025  258.36  261.80  245.93  252.35     252.35   99,696,500

# %%
df=df.reset_index(drop=True)
df
# Out:
#            Date    Open    High     Low   Close  Adj Close       Volume
# 0   Apr 8, 2025  245.00  250.44  217.80  221.86     221.86  171,603,500
# 1   Apr 9, 2025  224.69  274.69  223.88  272.20     272.20  219,433,400
# 2  Apr 10, 2025  260.00  262.49  239.33  252.40     252.40  181,722,600
# 3  Apr 11, 2025  251.84  257.74  241.36  252.31     252.31  128,948,100
# 4  Apr 14, 2025  258.36  261.80  245.93  252.35     252.35   99,696,500

# %%
import pandas as pd
df=pd.read_csv('./utils/tsla_history.csv')
# temp=df[df['Date']=='Aug 25, 2022']
# temp

# %%
nearest_split=df.iloc[3061:, :]

# %%
nearest_split=nearest_split.reset_index(drop=True)
nearest_split
# Out:
#              Date    Open    High     Low   Close  Adj Close       Volume
# 0    Aug 25, 2022  302.36  302.96  291.60  296.07     296.07   53,230,000
# 1    Aug 26, 2022  297.43  302.00  287.47  288.09     288.09   57,163,900
# 2    Aug 29, 2022  282.83  287.74  280.70  284.82     284.82   41,864,700
# 3    Aug 30, 2022  287.87  288.48  272.65  277.70     277.70   50,541,800
# 4    Aug 31, 2022  280.62  281.25  271.81  275.61     275.61   52,107,300
# ..            ...     ...     ...     ...     ...        ...          ...
# 656   Apr 8, 2025  245.00  250.44  217.80  221.86     221.86  171,603,500
# 657   Apr 9, 2025  224.69  274.69  223.88  272.20     272.20  219,433,400
# 658  Apr 10, 2025  260.00  262.49  239.33  252.40     252.40  181,722,600
# 659  Apr 11, 2025  251.84  257.74  241.36  252.31     252.31  128,948,100
# 660  Apr 14, 2025  258.36  261.80  245.93  252.35     252.35   99,696,500
#
# [661 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3722 non-null   object
#  1   Open       3722 non-null   float64
#  2   High       3722 non-null   float64
#  3   Low        3722 non-null   float64
#  4   Close      3722 non-null   float64
#  5   Adj Close  3722 non-null   float64
#  6   Volume     3722 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 203.7+ KB

# %%
close_price=np.array(df['Adj Close'])

# %%
X=[]
y=[]
# Out:
# 3722

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import math
import time

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scaler

# You should never fit on test data. 
# Fitting is where the model "learns," and you want your test set to remain unseen and unbiased.
# Out:
# MinMaxScaler()

# %%
# fit(train_data)	Learns min/max or mean/std from train_data
# transform()	Applies formula using learned values

# %%
print("Min:", scaler.data_min_)
print("Max:", scaler.data_max_)

all_scaled_data=scaler.fit_transform(df['Adj Close'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 all_scaled_data=scaler.fit_transform(df['Adj Close'])
#
# File /opt/miniconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File /opt/miniconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...
